# %%
from sklearn import datasets

iris = datasets.load_iris()

import pandas as pd

df = (pd.DataFrame(iris['data'], columns=iris['feature_names']).assign(target=iris['target']))
df.to_csv("my_data.csv", index=False)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'])

# %%
plt.scatter(df['petal length (cm)'], df['petal width (cm)'], c=df['target'])

# %%
# drop third row

# method 1
pd.concat([df.iloc[0:3], df.iloc[4:]])

# method 2
df_drop = df.drop([3], axis=0)
df_drop
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df_drop.index = list(range(149))
df_drop
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  5.0               3.6                1.4               0.2
# 4                  5.4               3.9                1.7               0.4
# ..                 ...               ...                ...               ...
# 144                6.7               3.0                5.2               2.3
# 145                6.3               2.5                5.0               1.9
# 146                6.5               3.0                5.2               2.0
# 147                6.2               3.4                5.4               2.3
# 148                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df_drop['petal length (cm)']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.4
# 4      1.7
#       ...
# 144    5.2
# 145    5.0
# 146    5.2
# 147    5.4
# 148    5.1
# Name: petal length (cm), Length: 149, dtype: float64

# %%
df['target']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
# IPython

pd.DataFrame.drop?

# %%
import inspect

# %%
print(inspect.getdoc(pd.DataFrame.drop))
# Out:
# Drop specified labels from rows or columns.
#
# Remove rows or columns by specifying label names and corresponding
# axis, or by specifying directly index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level. See the :ref:`user guide <advanced.shown_levels>`
# for more information about the now unused levels.
#
# Parameters
# ----------
# labels : single label or list-like
#     Index or column labels to drop. A tuple will be used as a single
#     label and not treated as a list-like.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Whether to drop labels from the index (0 or 'index') or
#     columns (1 or 'columns').
# index : single label or list-like
#     Alternative to specifying axis (``labels, axis=0``
#     is equivalent to ``index=labels``).
# columns : single label or list-like
#     Alternative to specifying axis (``labels, axis=1``
#     is equivalent to ``columns=labels``).
# ...

# %%
df.drop(['petal length (cm)'], axis=1)
# Out:
#      sepal length (cm)  sepal width (cm)  petal width (cm)  target
# 0                  5.1               3.5               0.2       0
# 1                  4.9               3.0               0.2       0
# 2                  4.7               3.2               0.2       0
# 3                  4.6               3.1               0.2       0
# 4                  5.0               3.6               0.2       0
# ..                 ...               ...               ...     ...
# 145                6.7               3.0               2.3       2
# 146                6.3               2.5               1.9       2
# 147                6.5               3.0               2.0       2
# 148                6.2               3.4               2.3       2
# 149                5.9               3.0               1.8       2
#
# [150 rows x 4 columns]

# %%
import numpy as np

df.assign(random_column = sum([[1.0, np.nan] for x in range(75)], start=[]))
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target  random_column
# ...

# %%
(
    df.assign(random_column = sum([[1.0, np.nan] for x in range(75)], start=[]))
    .dropna(subset=["random_column"], axis=0)
)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 4                  5.0               3.6                1.4               0.2
# 6                  4.6               3.4                1.4               0.3
# 8                  4.4               2.9                1.4               0.2
# ..                 ...               ...                ...               ...
# 140                6.7               3.1                5.6               2.4
# 142                5.8               2.7                5.1               1.9
# 144                6.7               3.3                5.7               2.5
# 146                6.3               2.5                5.0               1.9
# 148                6.2               3.4                5.4               2.3
#
#      target  random_column
# ...

# %%
(
    df.assign(random_column = sum([[1.0, np.nan] for x in range(75)], start=[]))
    .dropna(subset=[1], axis=1)
)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
(
    df.assign(random_column_1 = sum([[1.0, np.nan] for x in range(75)], start=[]))
    .assign(random_column_2 = sum([[np.nan, 2.0] for x in range(75)], start=[]))\
    .assign(random_column_2=lambda df: df['random_column_2'].fillna(0))
)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
(
    df.assign(random_column_1 = sum([[1.0, np.nan] for x in range(75)], start=[]))
    .assign(random_column_2 = sum([[np.nan, 2.0] for x in range(75)], start=[]))\
#     .assign(random_column_2=lambda df: df['random_column_2'].fillna(0))
    .assign(random_column_2=lambda df: df['random_column_2'].dropna().std())
)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...
